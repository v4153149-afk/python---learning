# %%
import json

with open("employees.json", "r") as file:
    data = json.load(file)

print("Original Data:\n")

for record in data:
    print(record)
# Out:
# Original Data:
#
# {'ID': 'E001', 'Name': 'Amit Kumar', 'Age': 25, 'Department': 'IT', 'Salary': 45000}
# {'ID': 'E002', 'Name': 'Priya Singh', 'Age': 28, 'Department': 'HR', 'Salary': 40000}
# {'ID': 'E003', 'Name': 'Rahul Verma', 'Age': 32, 'Department': 'Finance', 'Salary': 55000}
# {'ID': 'E004', 'Name': 'Neha Sharma', 'Age': 26, 'Department': 'Marketing', 'Salary': 42000}
# {'ID': 'E005', 'Name': 'Arjun Patel', 'Age': 30, 'Department': 'IT', 'Salary': 60000}

# %%
text_to_num = {
    "one": 1,
    "two": 2,
    "three": 3,
    "four": 4,
    "five": 5
}

def clean_data(data):
    for record in data:
        print(record)

        rating = record["depertment"].strip().lower()

        if rating in text_to_num:
            rating = text_to_num[rating]

# %%
# missing data
record.get("age")
raw_age = record.get("age")
if(raw_age == ''):
    user["age"] = none

# %%
def remove_duplicate(data):
    cleaned_data = []
    unique_record = set()

    for record in data:
        if record["name"].strip() in unique_record:
            continue

        unique_record.add(record["name"].strip())
        cleaned_data.append(record)

    return cleaned_data
